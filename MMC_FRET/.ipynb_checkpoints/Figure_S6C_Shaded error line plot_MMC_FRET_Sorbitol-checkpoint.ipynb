# %%
! pip install requests

# %%
! pip install pandas

# %%
import pandas as pd

# Load csv file from lacal repository
df1 = pd.read_csv('Figure_S6C_Sb_CrowdFRET_Processed.csv')
print(df1.head())  # Display the first few rows of the DataFrame

# %%
# install matplotlib library
! pip install matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# Define color gradient
def get_gradient_colors(start_color, end_color, n):
    cmap = mcolors.LinearSegmentedColormap.from_list("grad", [start_color, end_color])
    return [mcolors.rgb2hex(cmap(i / (n - 1))) for i in range(n)]

# Generate 9 colors (Isotonic + 8 Sb levels)
colors = get_gradient_colors("#b3b3b3", "#49c1bb", 9)

# Apply rolling mean for smoothing
for cond in ['Isotonic'] + [f'Sb_{i}mOsm/L' for i in range(50, 401, 50)]:
    df1[f'{cond}_Mean_smooth'] = df1[f'{cond}_Mean'].rolling(window=3, center=True).mean()
    df1[f'{cond}_SD_smooth'] = df1[f'{cond}_SD'].rolling(window=3, center=True).mean()

# Create the plot
plt.figure(figsize=(5,3))

# Plot each condition with gradient color
conditions = ['Isotonic'] + [f'Sb_{i}mOsm/L' for i in range(50, 401, 50)]
for i, cond in enumerate(conditions):
    color = colors[i]
    plt.plot(df1['TIME'], df1[f'{cond}_Mean_smooth'], label=cond, color=color)
    plt.fill_between(
        df1['TIME'],
        df1[f'{cond}_Mean_smooth'] - df1[f'{cond}_SD_smooth'],
        df1[f'{cond}_Mean_smooth'] + df1[f'{cond}_SD_smooth'],
        color=color, alpha=0.2
    )

# Set x range
xticks = np.arange(0, 1450, 200)
plt.xticks(xticks)
plt.tick_params(axis='both', labelsize=12)

# Set y-axis range
yticks = np.arange(0.4, 1.9, 0.2)
plt.yticks(yticks)

# Adjust spines
ax = plt.gca()
ax.spines['left'].set_position(('outward', 5))
ax.spines['bottom'].set_position(('outward', 20))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_bounds(0, 1450)
ax.spines['left'].set_bounds(0.4, 1.8)

# Customize the plot
plt.title('Crowd FRET', fontsize=16, family='Arial')
plt.xlabel('Time (min)', fontsize=14, family='Arial', labelpad=5)
plt.ylabel('Normalized mCitrine/mCerulean\n(525/475 nm)', fontsize=14, family='Arial', labelpad=5)
plt.grid(False)

# Legend
plt.legend(
    frameon=False,
    loc='center left',
    bbox_to_anchor=(1, 0.5),
    prop={'family': 'Arial', 'size': 12}
)

plt.subplots_adjust(right=0.75)

# Save the plot
plt.savefig('Figure_S6C_CrowdFRET_Sb_gradient.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Apply rolling mean for smoothing
df1['Isotonic_Mean_smooth'] = df1['Isotonic_Mean'].rolling(window=3, center=True).mean()
df1['Sb_50mOsm/L_Mean_smooth'] = df1['Sb_50mOsm/L_Mean'].rolling(window=3, center=True).mean()
df1['Sb_100mOsm/L_Mean_smooth'] = df1['Sb_100mOsm/L_Mean'].rolling(window=3, center=True).mean()
df1['Sb_150mOsm/L_Mean_smooth'] = df1['Sb_150mOsm/L_Mean'].rolling(window=3, center=True).mean()
df1['Sb_200mOsm/L_Mean_smooth'] = df1['Sb_200mOsm/L_Mean'].rolling(window=3, center=True).mean()
df1['Sb_250mOsm/L_Mean_smooth'] = df1['Sb_250mOsm/L_Mean'].rolling(window=3, center=True).mean()
df1['Sb_300mOsm/L_Mean_smooth'] = df1['Sb_300mOsm/L_Mean'].rolling(window=3, center=True).mean()
df1['Sb_350mOsm/L_Mean_smooth'] = df1['Sb_350mOsm/L_Mean'].rolling(window=3, center=True).mean()
df1['Sb_400mOsm/L_Mean_smooth'] = df1['Sb_400mOsm/L_Mean'].rolling(window=3, center=True).mean()
df1['Isotonic_SD_smooth'] = df1['Isotonic_SD'].rolling(window=3, center=True).mean()
df1['Sb_50mOsm/L_SD_smooth'] = df1['Sb_50mOsm/L_SD'].rolling(window=3, center=True).mean()
df1['Sb_100mOsm/L_SD_smooth'] = df1['Sb_100mOsm/L_SD'].rolling(window=3, center=True).mean()
df1['Sb_150mOsm/L_SD_smooth'] = df1['Sb_150mOsm/L_SD'].rolling(window=3, center=True).mean()
df1['Sb_200mOsm/L_SD_smooth'] = df1['Sb_200mOsm/L_SD'].rolling(window=3, center=True).mean()
df1['Sb_250mOsm/L_SD_smooth'] = df1['Sb_250mOsm/L_SD'].rolling(window=3, center=True).mean()
df1['Sb_300mOsm/L_SD_smooth'] = df1['Sb_300mOsm/L_SD'].rolling(window=3, center=True).mean()
df1['Sb_350mOsm/L_SD_smooth'] = df1['Sb_350mOsm/L_SD'].rolling(window=3, center=True).mean()
df1['Sb_400mOsm/L_SD_smooth'] = df1['Sb_400mOsm/L_SD'].rolling(window=3, center=True).mean()

# Create the plot
plt.figure(figsize=(5,3))
plt.plot(df1['TIME'], df1['Isotonic_Mean_smooth'], label='Isotonic', color='#003f5c')
plt.fill_between(df1['TIME'], df1['Isotonic_Mean_smooth'] - df1['Isotonic_SD_smooth'], df1['Isotonic_Mean_smooth'] + df1['Isotonic_SD_smooth'], color='#003f5c', alpha=0.2)
plt.plot(df1['TIME'], df1['Sb_50mOsm/L_Mean_smooth'], label='Sb_50mOsm/L', color='#2f4b7c')
plt.fill_between(df1['TIME'], df1['Sb_50mOsm/L_Mean_smooth'] - df1['Sb_50mOsm/L_SD_smooth'], df1['Sb_50mOsm/L_Mean_smooth'] + df1['Sb_50mOsm/L_SD_smooth'], color='#2f4b7c', alpha=0.2)
plt.plot(df1['TIME'], df1['Sb_100mOsm/L_Mean_smooth'], label='Sb_100mOsm/L', color='#665191')
plt.fill_between(df1['TIME'], df1['Sb_100mOsm/L_Mean_smooth'] - df1['Sb_100mOsm/L_SD_smooth'], df1['Sb_100mOsm/L_Mean_smooth'] + df1['Sb_100mOsm/L_SD_smooth'], color='#665191', alpha=0.2)
plt.plot(df1['TIME'], df1['Sb_200mOsm/L_Mean_smooth'], label='Sb_200mOsm/L', color='#d45087')
plt.fill_between(df1['TIME'], df1['Sb_200mOsm/L_Mean_smooth'] - df1['Sb_200mOsm/L_SD_smooth'], df1['Sb_200mOsm/L_Mean_smooth'] + df1['Sb_200mOsm/L_SD_smooth'], color='#d45087', alpha=0.2)
plt.plot(df1['TIME'], df1['Sb_400mOsm/L_Mean_smooth'], label='Sb_400mOsm/L', color='#ffc107')
plt.fill_between(df1['TIME'], df1['Sb_400mOsm/L_Mean_smooth'] - df1['Sb_400mOsm/L_SD_smooth'], df1['Sb_400mOsm/L_Mean_smooth'] + df1['Sb_400mOsm/L_SD_smooth'], color='#ffc107', alpha=0.2)

# Set x range
xticks = np.arange(0, 1460, 200)
plt.xticks(xticks)
plt.tick_params(axis='both', labelsize=12)

# Set y-axis range
yticks = np.arange(0.4, 1.9, 0.2)  # Start at 0.5, end at 1.6, with interval of 0.2. Include 1.5 by extending the range slightly
plt.yticks(yticks)

# Separate the (0,0) coordinate by moving the spines
ax = plt.gca()
ax.spines['left'].set_position(('outward', 5))  # Move the y-axis spine outward
ax.spines['bottom'].set_position(('outward', 20))  # Move the x-axis spine outward

# Hide the top and right spines
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

# Set the bounds for the bottom and left spines to start from the first tick
ax.spines['bottom'].set_bounds(0, 1460)
ax.spines['left'].set_bounds(0.4, 1.8)

# Customize the plot
plt.title('Crowd FRET', fontsize=16, family='Arial')
plt.xlabel('Time (min)', fontsize=14, family='Arial', labelpad=5)
plt.ylabel('Normalized mCitrine/mCerulean' + '\n' + '(525/475 nm)', fontsize=14, family='Arial', labelpad=5)
plt.grid(False)

# Customize the legend
plt.legend(
    frameon=False,
    loc='center left',
    bbox_to_anchor=(1,0.5),
    prop={'family': 'Arial', 'size': 12}
)

#Adjust the area of the legend
plt.subplots_adjust(right=0.75)  # Adjust the right boundary to make space

# Save the plot as a PDF
plt.savefig('Figure_S6C_CrowdFRET_Sb_Gradient.pdf', format='pdf', bbox_inches='tight')

# Display the plot
plt.show()
